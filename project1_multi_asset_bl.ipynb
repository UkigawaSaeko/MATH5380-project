# %% [markdown]
# # Project 1 Notebook: Long-Only Multi-Asset Portfolio with Black-Litterman Tilts
#
# 这个 notebook 使用教授给的 Excel 数据，完成：
# - 数据清洗与对齐
# - 市场权重与两组有统一故事线的观点（美国成长相对非美成长；投资级美综合债相对全球高收益）
# - Black-Litterman 预期收益
# - 年度再平衡（long-only + 权重和为1 + 相对市场单资产偏离±5%）
# - 月度回测与可视化
# - 关键统计量输出

# %%
import warnings
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import minimize

warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", 200)
plt.style.use("seaborn-v0_8")

# %%
# 1) 读取 Excel（默认在 notebook 上一级目录）
base_dir = Path.cwd()
excel_path = (base_dir / ".." / "Data for final project 1.xlsx").resolve()

if not excel_path.exists():
    # 如果你从别的目录启动 kernel，可以手动改这里
    excel_path = Path(r"E:\Columbia_Files\MATH5380\project\Data for final project 1.xlsx")

print("Using Excel:", excel_path)

returns_raw = pd.read_excel(excel_path, sheet_name="Index returns in USD")
mv_raw = pd.read_excel(excel_path, sheet_name="Market values in USD")

# 列名映射：把 market values 的名称对齐到 returns 命名
name_map = {
    "Bloomberg Barclays Global Inflation-Linked": "Bloomberg Barclays Global Inflation-Linked USD",
    "Bloomberg Barclays Municipal Bond": "Bloomberg Barclays US Municipal Bond",
    "Bloomberg Barclays Global High Yield": "Bloomberg Barclays Global High Yield USD",
}
mv_raw = mv_raw.rename(columns=name_map)

# 日期处理
def parse_yyyymmdd(x):
    return pd.to_datetime(str(int(x)), format="%Y%m%d")

returns_raw["Date"] = returns_raw["Date"].apply(parse_yyyymmdd)
mv_raw["Date"] = mv_raw["Date"].apply(parse_yyyymmdd)

returns_raw = returns_raw.sort_values("Date").reset_index(drop=True)
mv_raw = mv_raw.sort_values("Date").reset_index(drop=True)

print("Returns shape:", returns_raw.shape)
print("Market values shape:", mv_raw.shape)
# Out:
# Using Excel: E:\Columbia_Files\MATH5380\project\Data for final project 1.xlsx
# Returns shape: (300, 20)
# Market values shape: (223, 18)

# %%
# 2) 资产池：使用两张表共有资产（并且有市场权重）
common_assets = [c for c in returns_raw.columns if c in mv_raw.columns and c != "Date"]
print("Common assets:", len(common_assets))
print(common_assets)

returns = returns_raw[["Date"] + common_assets].copy()
mv = mv_raw[["Date"] + common_assets].copy()

# 后续按日期索引
returns = returns.set_index("Date")
mv = mv.set_index("Date")

# 月度收益必须是小数（文件已是小数）
assert returns.abs().max().max() < 1.0, "Returns seems not in decimal format."
# Out:
# Common assets: 17
# ['Russell 1000 Value', 'Russell 1000 Growth', 'Russell 2000 Value', 'Russell 2000 Growth', 'MSCI World Ex USA Value NR USD', 'MSCI World Ex USA Growth NR USD', 'MSCI World Ex USA Small Value NR USD', 'MSCI World Ex USA Small Growth NR USD', 'MSCI EM Value NR USD', 'MSCI EM Growth NR USD', 'MSCI EM Small Value NR USD', 'MSCI EM Small Growth NR USD', 'Bloomberg Barclays US Aggregate', 'Bloomberg Barclays Global Aggregate x USD', 'Bloomberg Barclays Global Inflation-Linked USD', 'Bloomberg Barclays US Municipal Bond', 'Bloomberg Barclays Global High Yield USD']

# %%
# 3) Black-Litterman + 优化函数

def nearest_psd(cov: np.ndarray, eps: float = 1e-8) -> np.ndarray:
    """简单修正，避免数值不稳定导致非正定。"""
    cov = (cov + cov.T) / 2
    vals, vecs = np.linalg.eigh(cov)
    vals = np.clip(vals, eps, None)
    return vecs @ np.diag(vals) @ vecs.T


def bl_posterior(pi, sigma, P, Q, tau=0.05, omega_scale=4.0):
    """
    pi: market implied returns (N,)
    sigma: annualized covariance (N,N)
    P: view matrix (K,N)
    Q: view returns (K,)
    omega_scale: >1 表示更弱置信度
    """
    ts = tau * sigma
    mid = P @ ts @ P.T
    omega = np.diag(np.diag(mid)) * omega_scale

    inv_ts = np.linalg.inv(ts)
    inv_omega = np.linalg.inv(omega)

    m = np.linalg.inv(inv_ts + P.T @ inv_omega @ P)
    mu_bl = m @ (inv_ts @ pi + P.T @ inv_omega @ Q)
    return mu_bl, omega


def optimize_long_only(mu, sigma, delta, w_mkt, max_dev=0.05):
    n = len(mu)

    def obj(w):
        return 0.5 * delta * (w @ sigma @ w) - (mu @ w)

    cons = ({"type": "eq", "fun": lambda w: np.sum(w) - 1.0},)

    # 每个资产相对市场权重偏离限制 ±5%
    lb = np.maximum(0.0, w_mkt - max_dev)
    ub = np.minimum(1.0, w_mkt + max_dev)
    bounds = list(zip(lb, ub))

    # 如果边界导致不可行，退化为普通 long-only
    if lb.sum() > 1.0 or ub.sum() < 1.0:
        bounds = [(0.0, 1.0)] * n

    w0 = w_mkt.copy()

    res = minimize(obj, w0, method="SLSQP", bounds=bounds, constraints=cons)
    if not res.success:
        # 兜底：去掉相对偏离约束，再求一次
        res = minimize(obj, w0, method="SLSQP", bounds=[(0.0, 1.0)] * n, constraints=cons)

    if not res.success:
        raise RuntimeError(f"Optimization failed: {res.message}")

    w = np.clip(res.x, 0.0, 1.0)
    w = w / w.sum()
    return w

# %%
# 4) 参数与观点（至少两个 tilt）
# ---------------------------------------------------------------------------
# 故事线（可写入报告 “Tilts / Views” 小节）：
#  在 2007 年后多轮流动性冲击与风险重定价环境下，用两条**互补的**相对收益观点，
#  形成统一逻辑：
#   (A) 权益：在**同一“成长”风格**下，美国 large-cap 相对**非美发达**成长的一点点优势
#       （美元市场深度、流动性与信息环境等——表述为**结构性、温和**的跨市场 premium，
#       而非短期动量）。
#   (B) 固收：在**信用/周期贝塔**维度上，偏好**投资级美国综合**相对**全球高收益**的温和 tilt
#       （久期+信用质量与 HY 的周期性的对比）。
#  两条线分别落在股票 / 债券，不重复押同一种 style-only 的 EM vs DM 或成长 vs 价值。
# ---------------------------------------------------------------------------
assets = common_assets
n = len(assets)
idx = {a: i for i, a in enumerate(assets)}

# 风险厌恶系数（全程固定）
delta = 2.5
# BL tau 与观点置信度（通过 omega_scale 控制）
tau = 0.05
omega_scale = 4.0  # 越大，观点越弱

P = np.zeros((2, n))
Q = np.zeros(2)

# View 1: Russell 1000 Growth 相对 MSCI World ex USA Growth（发达市场、同风格跨区域）
if "Russell 1000 Growth" in idx and "MSCI World Ex USA Growth NR USD" in idx:
    P[0, idx["Russell 1000 Growth"]] = 1.0
    P[0, idx["MSCI World Ex USA Growth NR USD"]] = -1.0
    Q[0] = 0.0075  # 年化相对超额 0.75%，幅度温和

# View 2: US Aggregate 相对 Global High Yield（固收、信用/质量维度）
if "Bloomberg Barclays US Aggregate" in idx and "Bloomberg Barclays Global High Yield USD" in idx:
    P[1, idx["Bloomberg Barclays US Aggregate"]] = 1.0
    P[1, idx["Bloomberg Barclays Global High Yield USD"]] = -1.0
    Q[1] = 0.004  # 年化 40bp 量级，避免与股票 spread 同尺度显得过强

print("delta=", delta, "tau=", tau, "omega_scale=", omega_scale)
print("P shape:", P.shape, "Q (annual long-short):", Q)
print("Narrative: (1) US vs ex-US **Growth**  (2) US IG Agg vs **Global HY**")
# Out:
# delta= 2.5 tau= 0.05 omega_scale= 4.0
# P shape: (2, 17) Q (annual long-short): [0.0075 0.004 ]
# Narrative: (1) US vs ex-US **Growth**  (2) US IG Agg vs **Global HY**

# %%
# 5) 年度再平衡 + 回测
# 规则：在每年 y 的最后一个「有市值」观测日 reb_date 处决定组合，用于持有「下一日历年」y+1 的全部月度收益。
#
# 无前视偏差要点（与作业 Note 2 一致）：
# - 协方差与 BL 仅用 reb_date 已实现的月度收益；绝不使用持有年 y+1 的收益。
# - 市值权重用当日 mv.loc[reb_date]（构造当日可得）。
# - 可选：不把 reb_date 当月收益放进协方差窗口（更保守）。默认 False，与常见「月末可得当月收益」假设一致。

EXCLUDE_REBALANCE_MONTH_FROM_COV = False

mv_year_end = mv.groupby(mv.index.year).tail(1).copy()
available_years = sorted(mv_year_end.index.year.unique())

weights_opt = {}
weights_mkt = {}
mu_pi_dict = {}
mu_bl_dict = {}
cov_dict = {}

port_rets = []
bmk_rets = []

for y in available_years:
    # 本循环内每年重算 Sigma, pi, mu_bl, w_opt（不跨 y 复用）
    reb_date = mv_year_end[mv_year_end.index.year == y].index.max()

    hold_mask = returns.index.year == (y + 1)
    if hold_mask.sum() == 0:
        continue

    hold_dates = returns.index[hold_mask]

    if EXCLUDE_REBALANCE_MONTH_FROM_COV:
        hist = returns.loc[returns.index < reb_date].tail(36)
    else:
        hist = returns.loc[returns.index <= reb_date].tail(36)

    if len(hist) < 36:
        continue

    # --- 无前视断言：估计样本与持有期样本不得重叠；持有期严格在 reb_date 之后 ---
    overlap = hist.index.intersection(hold_dates)
    assert overlap.empty, f"year y={y}: hist 与持有期日期重叠 {list(overlap[:3])}..."
    assert hold_dates.min() > reb_date, f"year y={y}: 持有期应晚于 reb_date"

    used_for_est = hist.index.max()
    assert used_for_est <= reb_date, f"year y={y}: 估计窗口越界 reb_date"
    assert hold_dates.min().year == y + 1, f"year y={y}: 持有期必须是日历年 {y+1}"

    # 市场权重（构造日可得）
    mv_vec = mv.loc[reb_date, assets].values.astype(float)
    w_mkt = mv_vec / mv_vec.sum()

    sigma = np.cov(hist[assets].values.T, ddof=1) * 12.0
    sigma = nearest_psd(sigma)

    pi = delta * (sigma @ w_mkt)

    mu_bl, omega = bl_posterior(pi, sigma, P, Q, tau=tau, omega_scale=omega_scale)

    w_opt = optimize_long_only(mu_bl, sigma, delta, w_mkt, max_dev=0.05)

    hold_year = y + 1
    weights_mkt[hold_year] = w_mkt
    weights_opt[hold_year] = w_opt
    mu_pi_dict[hold_year] = pi
    mu_bl_dict[hold_year] = mu_bl
    cov_dict[hold_year] = sigma

    r_next = returns.loc[hold_mask, assets]
    rp = r_next.values @ w_opt
    rb = r_next.values @ w_mkt

    port_rets.append(pd.Series(rp, index=r_next.index))
    bmk_rets.append(pd.Series(rb, index=r_next.index))

port_rets = pd.concat(port_rets).sort_index()
bmk_rets = pd.concat(bmk_rets).sort_index()

print("EXCLUDE_REBALANCE_MONTH_FROM_COV =", EXCLUDE_REBALANCE_MONTH_FROM_COV)
print("Look-ahead checks: passed (assertions in loop)")
print("Backtest months:", len(port_rets))
print("Start:", port_rets.index.min().date(), "End:", port_rets.index.max().date())
print("Years with weights:", len(weights_opt), sorted(weights_opt.keys())[:3], "...", sorted(weights_opt.keys())[-3:])
# Out:
# EXCLUDE_REBALANCE_MONTH_FROM_COV = False
# Look-ahead checks: passed (assertions in loop)
# Backtest months: 216
# Start: 2008-01-31 End: 2025-12-31
# Years with weights: 18 [2008, 2009, 2010] ... [2023, 2024, 2025]

# %% [markdown]
# ### 每年重算检查（与作业 “recalculate … annually” 对齐）
#
# **在 `for y in available_years:` 内部，对持有年 `y+1` 的组合，以下量均在当次再平衡时重新计算，而不是沿用上一年：**
#
# | 量 | 代码逻辑（要点） |
# |----|------------------|
# | **\(\Sigma\)** | 由截至 `reb_date` 的 `hist`（至少 36 个月）估计 `np.cov(...)*12`，再 `nearest_psd`。每年 `hist` 随 `y` 与 `reb_date` 更新。 |
# | **\(w^{mkt}\)** | `mv.loc[reb_date, assets]` 当日归一化，每年再平衡日可能不同。 |
# | **\(\pi\)** | `pi = delta * (sigma @ w_mkt)`，随当年的 \(\Sigma,w^{mkt}\) 而变。 |
# | **\(\mu_{BL}\)** | `bl_posterior(pi, sigma, P, Q, ...)`，随 \(\pi,\Sigma\) 而变；若 `P,Q` 不变，\(\mu_{BL}\) 仍**年年不同**（因 \(\pi,\Sigma\) 变）。 |
# | **\(w^*\)** | `optimize_long_only(mu_bl, sigma, ...)`，每年新解。 |
#
# **在循环外保持常数、未逐年更改的**：`P, Q, tau, omega_scale, delta`（项目说明允许 *views 可全程固定*，只要其它输入**每年**更新；本 notebook 采用常数 `Q`；若做“分段 `Q`”，需在报告中单独论证**不引入前视**的规则，见下节。）
#
# **前视控制**：`hist` 与持有期无交集、`hold_dates.min() > reb_date` 等 assert 与 Note 2 一致。
#
# ---
#
# ### 进阶讨论：是否按制度/危机或宏观**调整 `Q`（不实现，仅方法学）**
#
# 若希望**增强经济叙事**又避免**前视质疑**，可讨论（不必编码）以下**可行**方向；核心原则是：在**每个再平衡日 `t=reb_date`** 只能使用 **\(t\) 及以前** 可观测或**事先公布** 的信息来设定当年的相对收益观点。
#
# 1. **预先固定、样本外已公布的“制度/分段”**
#    例如以 **NBER 衰退起止**、**美联储 QE 起止**（均为事后研究常用、日期事后修订存在——若用**初值**在实时中仍有噪声）划分区间，并在**项目开始前**写清规则。风险：部分标签在当时并未实时可得，需在报告中承认并**弱化**对“当时可得”的声称，或仅作**思想实验**。
#
# 2. **仅依赖 \(t\) 前已实现数据的** **滚动/递归** 规则（无未来函数）
#    例如用截至 \(t\) 的 **VIX 水平**、**信用利差**、**实际利率** 等，按**提前写死**的阈值（在样本开始前固定）将当年 `Q` 乘一个系数，或换用预先规定的一套“温和/更强”`Q`。**关键**：阈值与映射必须在全样本**同一套**、**不根据整段回测调参**，否则有数据窥探嫌疑。
#
# 3. **不做时间变 `Q`，而用 \(\Omega\) 或 `omega_scale` 做状态依赖**（理念讨论）
#    课堂上“观点置信”常体现在 \(\Omega\) 上。可讨论：在危机期**增大**对观点不确定度（等价于**更弱**地相信 `Q`），而 `Q` 本身不变。实现时同样只许用 **\(t\)** 前数据驱动该缩放（如滚动波动率、利差），并预先声明。
#
# 4. **应避免的**前视/不当做法
#    - 用**持有年** \(y+1\) 的收益、GDP、或当年才被修订的经济数据，反推**上一年末**的 `Q`。
#    - 在整段样本上**优化** `Q` 与分段点以最大化回测表现（过度拟合 + 前视感）。
#    - 用**全样本**算好的危机日期集合再分段，且未说明“当时的人能否识别”。
#
# **结论（写作建议）**：当前实现 = **常数 `Q` + 每年重算 \(\Sigma,\pi,\mu_{BL},w\)**，已满足作业对“**每年**更新**其它输入**”的要求；上列内容可作为**报告中的扩展讨论**，表明你理解**时间变观点**的识别与前视问题，无需改代码即加分叙述。

# %%
# 6) 结果指标

def ann_geo_return(r):
    return (1 + r).prod() ** (12 / len(r)) - 1

def ann_vol(r):
    return r.std(ddof=1) * np.sqrt(12)

active = port_rets - bmk_rets

summary = pd.DataFrame({
    "Portfolio": [ann_geo_return(port_rets), ann_vol(port_rets)],
    "Benchmark": [ann_geo_return(bmk_rets), ann_vol(bmk_rets)]
}, index=["Geo Ann Return", "Ann Volatility"])

active_stats = pd.Series({
    "Ann Active Return (Arithmetic)": active.mean() * 12,
    "Tracking Error (Ann)": ann_vol(active),
})
active_stats["Information Ratio"] = active_stats["Ann Active Return (Arithmetic)"] / active_stats["Tracking Error (Ann)"]

summary, active_stats
# Out:
# (                Portfolio  Benchmark
#  Geo Ann Return   0.047627   0.044409
#  Ann Volatility   0.087823   0.100079,
#  Ann Active Return (Arithmetic)    0.001917
#  Tracking Error (Ann)              0.017063
#  Information Ratio                 0.112336
#  dtype: float64)

# %%
# 7) 可视化：Growth of $1 + 年度权重热力图

growth = pd.DataFrame({
    "Portfolio": (1 + port_rets).cumprod(),
    "Benchmark": (1 + bmk_rets).cumprod(),
})

fig, ax = plt.subplots(1, 1, figsize=(10, 5))
growth.plot(ax=ax)
ax.set_title("Growth of $1")
ax.set_ylabel("Gross Return Index")
ax.grid(True, alpha=0.3)
plt.show()

w_opt_df = pd.DataFrame(weights_opt, index=assets).T

fig, ax = plt.subplots(figsize=(12, 6))
im = ax.imshow(w_opt_df.values, aspect="auto")
ax.set_title("Optimal Weights by Year")
ax.set_xticks(range(len(assets)))
ax.set_xticklabels(assets, rotation=90)
ax.set_yticks(range(len(w_opt_df.index)))
ax.set_yticklabels(w_opt_df.index)
fig.colorbar(im, ax=ax, shrink=0.7)
plt.tight_layout()
plt.show()

# %%
# 8) 导出老师要求里常见的年度表（Weights / Parameters / Expected Returns）

weights_mkt_df = pd.DataFrame(weights_mkt, index=assets).T
weights_opt_df = pd.DataFrame(weights_opt, index=assets).T
pi_df = pd.DataFrame(mu_pi_dict, index=assets).T
bl_df = pd.DataFrame(mu_bl_dict, index=assets).T

params_df = pd.DataFrame({
    "delta": [delta] * len(weights_opt_df),
    "tau": [tau] * len(weights_opt_df),
    "omega_scale": [omega_scale] * len(weights_opt_df),
}, index=weights_opt_df.index)

print("Market weights (head):")
display(weights_mkt_df.head())
print("Optimal weights (head):")
display(weights_opt_df.head())
print("Expected returns - pi (head):")
display(pi_df.head())
print("Expected returns - BL (head):")
display(bl_df.head())
print("Parameters:")
display(params_df.head())
# Out:
# Market weights (head):
#       Russell 1000 Value  Russell 1000 Growth  Russell 2000 Value  \
# 2008            0.105894             0.116790            0.008966
# 2009            0.085050             0.084437            0.007504
# 2010            0.082034             0.084239            0.007250
# 2011            0.086912             0.088478            0.007760
# 2012            0.087576             0.087230            0.007466
#
#       Russell 2000 Growth  MSCI World Ex USA Value NR USD  \
# 2008             0.010368                        0.112815
# 2009             0.006762                        0.077836
# 2010             0.006860                        0.084126
# 2011             0.008136                        0.080998
# 2012             0.007499                        0.071997
#
#       MSCI World Ex USA Growth NR USD  MSCI World Ex USA Small Value NR USD  \
# 2008                         0.114770                              0.012333
# 2009                         0.082677                              0.006758
# 2010                         0.085389                              0.010242
# 2011                         0.084398                              0.011322
# 2012                         0.072229                              0.009962
#
#       MSCI World Ex USA Small Growth NR USD  MSCI EM Value NR USD  \
# 2008                               0.013049              0.027059
# 2009                               0.007671              0.016618
# 2010                               0.010247              0.023744
# 2011                               0.012001              0.025593
# 2012                               0.010004              0.021123
#
#       MSCI EM Growth NR USD  MSCI EM Small Value NR USD  \
# 2008               0.025616                    0.003689
# 2009               0.015179                    0.002117
# 2010               0.024559                    0.003185
# 2011               0.025708                    0.003579
# 2012               0.021972                    0.002779
#
#       MSCI EM Small Growth NR USD  Bloomberg Barclays US Aggregate  \
# 2008                     0.003643                         0.152601
# 2009                     0.002086                         0.218227
# 2010                     0.003280                         0.204433
# 2011                     0.003541                         0.203627
# 2012                     0.002786                         0.215712
#
#       Bloomberg Barclays Global Aggregate x USD  \
# 2008                                   0.242529
# 2009                                   0.331605
# 2010                                   0.313518
# 2011                                   0.302291
# 2012                                   0.320389
#
#       Bloomberg Barclays Global Inflation-Linked USD  \
# 2008                                        0.018546
# 2009                                        0.023331
# 2010                                        0.021263
# 2011                                        0.020546
# 2012                                        0.024547
#
#       Bloomberg Barclays US Municipal Bond  \
# 2008                              0.016292
# 2009                              0.020465
# 2010                              0.018378
# 2011                              0.016322
# 2012                              0.017390
#
#       Bloomberg Barclays Global High Yield USD
# 2008                                  0.015041
# 2009                                  0.011676
# 2010                                  0.017254
# 2011                                  0.018788
# 2012                                  0.019339
# Optimal weights (head):
#       Russell 1000 Value  Russell 1000 Growth  Russell 2000 Value  \
# 2008            0.055894             0.160159                 0.0
# 2010                              0.007257
# 2011                              0.006483
# 2012                             -0.000469
#
#       Bloomberg Barclays Global High Yield USD
# 2008                                  0.004447
# 2009                                  0.029693
# 2010                                  0.046607
# 2011                                  0.054215
# 2012                                  0.026327
# Parameters:
#       delta   tau  omega_scale
# 2008    2.5  0.05          4.0
# 2009    2.5  0.05          4.0
# 2010    2.5  0.05          4.0
# 2011    2.5  0.05          4.0
# 2012    2.5  0.05          4.0

# %%
# 9) 最后一年 Covariances / Volatilities / Correlations

final_year = max(cov_dict.keys())
final_cov = pd.DataFrame(cov_dict[final_year], index=assets, columns=assets)
final_vol = pd.Series(np.sqrt(np.diag(final_cov)), index=assets, name="Ann Vol")
final_cor = final_cov.div(final_vol, axis=0).div(final_vol, axis=1)

print("Final year:", final_year)
print("Covariances:")
display(final_cov)
print("Volatilities:")
display(final_vol.to_frame())
print("Correlations:")
display(final_cor)
# Out:
# Final year: 2025
# Covariances:
#                                                 Russell 1000 Value  \
# Russell 1000 Value                                        0.028533
# Russell 1000 Growth                                       0.026336
# Russell 2000 Value                                        0.036701
# Russell 2000 Growth                                       0.035440
# MSCI World Ex USA Value NR USD                            0.023465
# MSCI World Ex USA Growth NR USD                           0.027119
# MSCI World Ex USA Small Value NR USD                      0.025540
# MSCI World Ex USA Small Growth NR USD                     0.029016
# MSCI EM Value NR USD                                      0.016858
# MSCI EM Growth NR USD                                     0.018704
# MSCI EM Small Value NR USD                                0.016872
# MSCI EM Small Growth NR USD                               0.018587
# Bloomberg Barclays US Aggregate                           0.009064
# Bloomberg Barclays Global Aggregate x USD                 0.013260
# Bloomberg Barclays Global Inflation-Linked USD            0.015630
# Bloomberg Barclays US Municipal Bond                      0.008711
# Bloomberg Barclays Global High Yield USD                  0.013582
#
#                                                 Russell 1000 Growth  \
# Russell 1000 Value                                         0.026336
# Russell 1000 Growth                                        0.042514
# Russell 2000 Value                                         0.032966
# Russell 2000 Growth                                        0.039916
# MSCI World Ex USA Value NR USD                             0.019267
# MSCI World Ex USA Growth NR USD                            0.033002
# MSCI World Ex USA Small Value NR USD                       0.022841
# MSCI World Ex USA Small Growth NR USD                      0.032619
# MSCI EM Value NR USD                                       0.019012
# MSCI EM Growth NR USD                                      0.023697
# MSCI EM Small Value NR USD                                 0.019784
# MSCI EM Small Growth NR USD                                0.025457
# Bloomberg Barclays US Aggregate                            0.011050
# Bloomberg Barclays Global Aggregate x USD                  0.014461
# Bloomberg Barclays Global Inflation-Linked USD             0.018346
# Bloomberg Barclays US Municipal Bond                       0.010972
# Bloomberg Barclays Global High Yield USD                   0.015549
#
#                                                 Russell 2000 Value  \
# Russell 1000 Value                                        0.036701
# Russell 1000 Growth                                       0.032966
# Russell 2000 Value                                        0.056492
# Russell 2000 Growth                                       0.053909
# MSCI World Ex USA Value NR USD                            0.028796
# MSCI World Ex USA Growth NR USD                           0.032619
# MSCI World Ex USA Small Value NR USD                      0.033519
# MSCI World Ex USA Small Growth NR USD                     0.038040
# MSCI EM Value NR USD                                      0.019843
# MSCI EM Growth NR USD                                     0.021087
# MSCI EM Small Value NR USD                                0.020770
# Bloomberg Barclays Global High Yield USD                                        0.009087
# Volatilities:
#                                                  Ann Vol
# Russell 1000 Value                              0.168916
# Russell 1000 Growth                             0.206188
# Russell 2000 Value                              0.237681
# Russell 2000 Growth                             0.243329
# MSCI World Ex USA Value NR USD                  0.161438
# MSCI World Ex USA Growth NR USD                 0.189677
# MSCI World Ex USA Small Value NR USD            0.174922
# MSCI World Ex USA Small Growth NR USD           0.199732
# MSCI EM Value NR USD                            0.161875
# MSCI EM Growth NR USD                           0.195490
# MSCI EM Small Value NR USD                      0.144222
# MSCI EM Small Growth NR USD                     0.165901
# Bloomberg Barclays US Aggregate                 0.078319
# Bloomberg Barclays Global Aggregate x USD       0.109363
# Bloomberg Barclays Global Inflation-Linked USD  0.116647
# Bloomberg Barclays US Municipal Bond            0.076583
# Bloomberg Barclays Global High Yield USD        0.095325
# Correlations:
#                                                 Russell 1000 Value  \
# Russell 1000 Value                                        1.000000
# Russell 1000 Growth                                       0.756169
# Russell 2000 Value                                        0.914136
# Russell 2000 Growth                                       0.862247
# MSCI World Ex USA Value NR USD                            0.860487
# MSCI World Ex USA Growth NR USD                           0.846407
# MSCI World Ex USA Small Value NR USD                      0.864386
# MSCI World Ex USA Small Growth NR USD                     0.860055
# MSCI EM Value NR USD                                      0.616542
# MSCI EM Growth NR USD                                     0.566424
# MSCI EM Small Value NR USD                                0.692559
# MSCI EM Small Growth NR USD                               0.663265
# Bloomberg Barclays US Aggregate                           0.685161
# Bloomberg Barclays Global Aggregate x USD                 0.717776
# Bloomberg Barclays Global Inflation-Linked USD            0.793257
# Bloomberg Barclays US Municipal Bond                      0.673389
# Bloomberg Barclays Global High Yield USD                  0.843499
#
#                                                 Russell 1000 Growth  \
# Russell 1000 Value                                         0.756169
# Russell 1000 Growth                                        1.000000
# Russell 2000 Value                                         0.672675
# Russell 2000 Growth                                        0.795593
# MSCI World Ex USA Value NR USD                             0.578816
# MSCI World Ex USA Growth NR USD                            0.843851
# MSCI World Ex USA Small Value NR USD                       0.633309
# MSCI World Ex USA Small Growth NR USD                      0.792069
# MSCI EM Value NR USD                                       0.569621
# MSCI EM Growth NR USD                                      0.587913
# MSCI EM Small Value NR USD                                 0.665288
# MSCI EM Small Growth NR USD                                0.744207
# Bloomberg Barclays US Aggregate                            0.684284
# Bloomberg Barclays Global Aggregate x USD                  0.641287
# Bloomberg Barclays Global Inflation-Linked USD             0.762794
# Bloomberg Barclays US Municipal Bond                       0.694873
# Bloomberg Barclays Global High Yield USD                   0.791097
#
#                                                 Russell 2000 Value  \
# Russell 1000 Value                                        0.914136
# Russell 1000 Growth                                       0.672675
# Russell 2000 Value                                        1.000000
# Russell 2000 Growth                                       0.932125
# MSCI World Ex USA Value NR USD                            0.750476
# MSCI World Ex USA Growth NR USD                           0.723545
# MSCI World Ex USA Small Value NR USD                      0.806208
# MSCI World Ex USA Small Growth NR USD                     0.801302
# MSCI EM Value NR USD                                      0.515732
# MSCI EM Growth NR USD                                     0.453832
# MSCI EM Small Value NR USD                                0.605917
# MSCI EM Small Growth NR USD                               0.579544
# Bloomberg Barclays US Aggregate                           0.614467
# Bloomberg Barclays Global Aggregate x USD                 0.614889
# Bloomberg Barclays Global Inflation-Linked USD            0.695645
# Bloomberg Barclays US Municipal Bond                      0.591618
# Bloomberg Barclays Global High Yield USD                  0.744785
#
#                                                 Russell 2000 Growth  \
# Russell 1000 Value                                         0.862247
# Russell 1000 Growth                                        0.795593
# Russell 2000 Value                                         0.932125
# Russell 2000 Growth                                        1.000000
# MSCI World Ex USA Value NR USD                             0.631518
# MSCI World Ex USA Growth NR USD                            0.775653
# MSCI World Ex USA Small Value NR USD                       0.719806
# MSCI World Ex USA Small Growth NR USD                      0.812089
# MSCI EM Value NR USD                                       0.496069
# MSCI EM Growth NR USD                                      0.465546
# MSCI EM Small Value NR USD                                 0.578089
# MSCI EM Small Growth NR USD                                0.613280
# Bloomberg Barclays US Aggregate                            0.649573
# Bloomberg Barclays Global Aggregate x USD                  0.608146
# Bloomberg Barclays Global Inflation-Linked USD             0.699917
# Bloomberg Barclays US Municipal Bond                       0.641865
# Bloomberg Barclays Global High Yield USD                   0.732495
#
#                                                 MSCI World Ex USA Value NR USD  \
# Russell 1000 Value                                                    0.860487
# Russell 1000 Growth                                                   0.578816
# Russell 2000 Value                                                    0.750476
# Russell 2000 Growth                                                   0.631518
# MSCI World Ex USA Value NR USD                                        1.000000
# MSCI World Ex USA Growth NR USD                                       0.833869
# MSCI World Ex USA Small Value NR USD                                  0.963155
# MSCI World Ex USA Small Growth NR USD                                 0.870631
# MSCI EM Value NR USD                                                  0.787913
# MSCI EM Growth NR USD                                                 0.703030
# MSCI EM Small Value NR USD                                            0.796992
# MSCI EM Small Growth NR USD                                           0.740101
# Bloomberg Barclays US Aggregate                                       0.716946
# Bloomberg Barclays Global Aggregate x USD                             0.809325
# Bloomberg Barclays Global Inflation-Linked USD                        0.800464
# Bloomberg Barclays US Municipal Bond                                  0.679260
# Bloomberg Barclays Global High Yield USD                              0.873549
#
#                                                 MSCI World Ex USA Growth NR USD  \
# Russell 1000 Value                                                     0.846407
# Russell 1000 Growth                                                    0.843851
# Russell 2000 Value                                                     0.723545
# Russell 2000 Growth                                                    0.775653
# MSCI World Ex USA Value NR USD                                         0.833869
# MSCI World Ex USA Growth NR USD                                        1.000000
# MSCI World Ex USA Small Value NR USD                                   0.878455
# MSCI World Ex USA Small Growth NR USD                                  0.961785
# MSCI EM Value NR USD                                                   0.748714
# MSCI EM Growth NR USD                                                  0.727130
# MSCI EM Small Value NR USD                                             0.789363
# MSCI EM Small Growth NR USD                                            0.813111
# Bloomberg Barclays US Aggregate                                        0.837461
# Bloomberg Barclays Global Aggregate x USD                              0.856401
# Bloomberg Barclays Global Inflation-Linked USD                         0.897758
# Bloomberg Barclays US Municipal Bond                                   0.839197
# Bloomberg Barclays Global High Yield USD                               0.908306
#
#                                                 MSCI World Ex USA Small Value NR USD  \
# Russell 1000 Value                                                          0.864386
# Russell 1000 Growth                                                         0.633309
# Russell 2000 Value                                                          0.806208
# Russell 2000 Growth                                                         0.719806
# MSCI World Ex USA Value NR USD                                              0.963155
# MSCI World Ex USA Growth NR USD                                             0.878455
# MSCI World Ex USA Small Value NR USD                                        1.000000
# MSCI World Ex USA Small Growth NR USD                                       0.944799
# MSCI EM Value NR USD                                                        0.776023
# MSCI EM Growth NR USD                                                       0.714418
# MSCI EM Small Value NR USD                                                  0.824377
# MSCI EM Small Growth NR USD                                                 0.776897
# Bloomberg Barclays US Aggregate                                             0.781133
# Bloomberg Barclays Global Aggregate x USD                                   0.844468
# Bloomberg Barclays Global Inflation-Linked USD                              0.859288
# Bloomberg Barclays US Municipal Bond                                        0.732285
# Bloomberg Barclays Global High Yield USD                                    0.910072
#
#                                                 MSCI World Ex USA Small Growth NR USD  \
# Russell 1000 Value                                                           0.860055
# Russell 1000 Growth                                                          0.792069
# Russell 2000 Value                                                           0.801302
# Russell 2000 Growth                                                          0.812089
# MSCI World Ex USA Value NR USD                                               0.870631
# MSCI World Ex USA Growth NR USD                                              0.961785
# MSCI World Ex USA Small Value NR USD                                         0.944799
# MSCI World Ex USA Small Growth NR USD                                        1.000000
# MSCI EM Value NR USD                                                         0.753213
# MSCI EM Growth NR USD                                                        0.728401
# MSCI EM Small Value NR USD                                                   0.826742
# MSCI EM Small Growth NR USD                                                  0.835536
# Bloomberg Barclays US Aggregate                                              0.839092
# Bloomberg Barclays Global Aggregate x USD                                    0.858949
# Bloomberg Barclays Global Inflation-Linked USD                               0.893798
# Bloomberg Barclays US Municipal Bond                                         0.814002
# Bloomberg Barclays Global High Yield USD                                     0.938112
#
#                                                 MSCI EM Value NR USD  \
# Russell 1000 Value                                          0.616542
# Russell 1000 Growth                                         0.569621
# Russell 2000 Value                                          0.515732
# Russell 2000 Growth                                         0.496069
# MSCI World Ex USA Value NR USD                              0.787913
# MSCI World Ex USA Growth NR USD                             0.748714
# MSCI World Ex USA Small Value NR USD                        0.776023
# MSCI World Ex USA Small Growth NR USD                       0.753213
# MSCI EM Value NR USD                                        1.000000
# MSCI EM Growth NR USD                                       0.961606
# MSCI EM Small Value NR USD                                  0.890388
# MSCI EM Small Growth NR USD                                 0.879435
# Bloomberg Barclays US Aggregate                             0.707246
# Bloomberg Barclays Global Aggregate x USD                   0.777756
# Bloomberg Barclays Global Inflation-Linked USD              0.730137
# Bloomberg Barclays US Municipal Bond                        0.740257
# Bloomberg Barclays Global High Yield USD                    0.775174
#
#                                                 MSCI EM Growth NR USD  \
# Russell 1000 Value                                           0.566424
# Russell 1000 Growth                                          0.587913
# Russell 2000 Value                                           0.453832
# Russell 2000 Growth                                          0.465546
# MSCI World Ex USA Value NR USD                               0.703030
# MSCI World Ex USA Growth NR USD                              0.727130
# MSCI World Ex USA Small Value NR USD                         0.714418
# MSCI World Ex USA Small Growth NR USD                        0.728401
# MSCI EM Value NR USD                                         0.961606
# MSCI EM Growth NR USD                                        1.000000
# MSCI EM Small Value NR USD                                   0.846085
# MSCI EM Small Growth NR USD                                  0.872613
# Bloomberg Barclays US Aggregate                              0.706588
# Bloomberg Barclays Global Aggregate x USD                    0.748016
# Bloomberg Barclays Global Inflation-Linked USD               0.707319
# Bloomberg Barclays US Municipal Bond                         0.775849
# Bloomberg Barclays Global High Yield USD                     0.763148
#
#                                                 MSCI EM Small Value NR USD  \
# Russell 1000 Value                                                0.692559
# Russell 1000 Growth                                               0.665288
# Russell 2000 Value                                                0.605917
# Russell 2000 Growth                                               0.578089
# MSCI World Ex USA Value NR USD                                    0.796992
# MSCI World Ex USA Growth NR USD                                   0.789363
# MSCI World Ex USA Small Value NR USD                              0.824377
# MSCI World Ex USA Small Growth NR USD                             0.826742
# MSCI EM Value NR USD                                              0.890388
# MSCI EM Growth NR USD                                             0.846085
# MSCI EM Small Value NR USD                                        1.000000
# MSCI EM Small Growth NR USD                                       0.962304
# Bloomberg Barclays US Aggregate                                   0.652944
# Bloomberg Barclays Global Aggregate x USD                         0.715793
# Bloomberg Barclays Global Inflation-Linked USD                    0.723472
# Bloomberg Barclays US Municipal Bond                              0.693461
# Bloomberg Barclays Global High Yield USD                          0.853386
#
#                                                 MSCI EM Small Growth NR USD  \
# Russell 1000 Value                                                 0.663265
# Russell 1000 Growth                                                0.744207
# Russell 2000 Value                                                 0.579544
# Russell 2000 Growth                                                0.613280
# MSCI World Ex USA Value NR USD                                     0.740101
# MSCI World Ex USA Growth NR USD                                    0.813111
# MSCI World Ex USA Small Value NR USD                               0.776897
# MSCI World Ex USA Small Growth NR USD                              0.835536
# MSCI EM Value NR USD                                               0.879435
# MSCI EM Growth NR USD                                              0.872613
# MSCI EM Small Value NR USD                                         0.962304
# MSCI EM Small Growth NR USD                                        1.000000
# Bloomberg Barclays US Aggregate                                    0.653670
# Bloomberg Barclays Global Aggregate x USD                          0.695547
# Bloomberg Barclays Global Inflation-Linked USD                     0.710824
# Bloomberg Barclays US Municipal Bond                               0.716925
# Bloomberg Barclays Global High Yield USD                           0.851231
#
#                                                 Bloomberg Barclays US Aggregate  \
# Russell 1000 Value                                                     0.685161
# Russell 1000 Growth                                                    0.684284
# Russell 2000 Value                                                     0.614467
# Russell 2000 Growth                                                    0.649573
# MSCI World Ex USA Value NR USD                                         0.716946
# MSCI World Ex USA Growth NR USD                                        0.837461
# MSCI World Ex USA Small Value NR USD                                   0.781133
# MSCI World Ex USA Small Growth NR USD                                  0.839092
# MSCI EM Value NR USD                                                   0.707246
# MSCI EM Growth NR USD                                                  0.706588
# MSCI EM Small Value NR USD                                             0.652944
# MSCI EM Small Growth NR USD                                            0.653670
# Bloomberg Barclays US Aggregate                                        1.000000
# Bloomberg Barclays Global Aggregate x USD                              0.937476
# Bloomberg Barclays Global Inflation-Linked USD                         0.898759
# Bloomberg Barclays US Municipal Bond                                   0.920930
# Bloomberg Barclays Global High Yield USD                               0.817953
#
#                                                 Bloomberg Barclays Global Aggregate x USD  \
# Russell 1000 Value                                                               0.717776
# Russell 1000 Growth                                                              0.641287
# Russell 2000 Value                                                               0.614889
# Russell 2000 Growth                                                              0.608146
# MSCI World Ex USA Value NR USD                                                   0.809325
# MSCI World Ex USA Growth NR USD                                                  0.856401
# MSCI World Ex USA Small Value NR USD                                             0.844468
# MSCI World Ex USA Small Growth NR USD                                            0.858949
# MSCI EM Value NR USD                                                             0.777756
# MSCI EM Growth NR USD                                                            0.748016
# MSCI EM Small Value NR USD                                                       0.715793
# MSCI EM Small Growth NR USD                                                      0.695547
# Bloomberg Barclays US Aggregate                                                  0.937476
# Bloomberg Barclays Global Aggregate x USD                                        1.000000
# Bloomberg Barclays Global Inflation-Linked USD                                   0.935527
# Bloomberg Barclays US Municipal Bond                                             0.884557
# Bloomberg Barclays Global High Yield USD                                         0.870612
#
#                                                 Bloomberg Barclays Global Inflation-Linked USD  \
# Russell 1000 Value                                                                    0.793257
# Russell 1000 Growth                                                                   0.762794
# Russell 2000 Value                                                                    0.695645
# Russell 2000 Growth                                                                   0.699917
# MSCI World Ex USA Value NR USD                                                        0.800464
# MSCI World Ex USA Growth NR USD                                                       0.897758
# MSCI World Ex USA Small Value NR USD                                                  0.859288
# MSCI World Ex USA Small Growth NR USD                                                 0.893798
# MSCI EM Value NR USD                                                                  0.730137
# MSCI EM Growth NR USD                                                                 0.707319
# MSCI EM Small Value NR USD                                                            0.723472
# MSCI EM Small Growth NR USD                                                           0.710824
# Bloomberg Barclays US Aggregate                                                       0.898759
# Bloomberg Barclays Global Aggregate x USD                                             0.935527
# Bloomberg Barclays Global Inflation-Linked USD                                        1.000000
# Bloomberg Barclays US Municipal Bond                                                  0.839688
# Bloomberg Barclays Global High Yield USD                                              0.877413
#
#                                                 Bloomberg Barclays US Municipal Bond  \
# Russell 1000 Value                                                          0.673389
# Russell 1000 Growth                                                         0.694873
# Russell 2000 Value                                                          0.591618
# Russell 2000 Growth                                                         0.641865
# MSCI World Ex USA Value NR USD                                              0.679260
# MSCI World Ex USA Growth NR USD                                             0.839197
# MSCI World Ex USA Small Value NR USD                                        0.732285
# MSCI World Ex USA Small Growth NR USD                                       0.814002
# MSCI EM Value NR USD                                                        0.740257
# MSCI EM Growth NR USD                                                       0.775849
# MSCI EM Small Value NR USD                                                  0.693461
# MSCI EM Small Growth NR USD                                                 0.716925
# Bloomberg Barclays US Aggregate                                             0.920930
# Bloomberg Barclays Global Aggregate x USD                                   0.884557
# Bloomberg Barclays Global Inflation-Linked USD                              0.839688
# Bloomberg Barclays US Municipal Bond                                        1.000000
# Bloomberg Barclays Global High Yield USD                                    0.813006
#
#                                                 Bloomberg Barclays Global High Yield USD
# Russell 1000 Value                                                              0.843499
# Russell 1000 Growth                                                             0.791097
# Russell 2000 Value                                                              0.744785
# Russell 2000 Growth                                                             0.732495
# MSCI World Ex USA Value NR USD                                                  0.873549
# MSCI World Ex USA Growth NR USD                                                 0.908306
# MSCI World Ex USA Small Value NR USD                                            0.910072
# MSCI World Ex USA Small Growth NR USD                                           0.938112
# MSCI EM Value NR USD                                                            0.775174
# MSCI EM Growth NR USD                                                           0.763148
# MSCI EM Small Value NR USD                                                      0.853386
# MSCI EM Small Growth NR USD                                                     0.851231
# Bloomberg Barclays US Aggregate                                                 0.817953
# Bloomberg Barclays Global Aggregate x USD                                       0.870612
# Bloomberg Barclays Global Inflation-Linked USD                                  0.877413
# Bloomberg Barclays US Municipal Bond                                            0.813006
# Bloomberg Barclays Global High Yield USD                                        1.000000
